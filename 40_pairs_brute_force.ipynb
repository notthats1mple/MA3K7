# %%
first_term = 0
second_term = 0

sequence = [first_term, second_term]

max_iterations = 1000
current_iteration = 0

while current_iteration < max_iterations:
    next_term = (first_term + second_term) % 10
    sequence.append(next_term)
    first_term, second_term = second_term, next_term
    current_iteration += 1
    if len(sequence) > 4 and sequence[-4:] == sequence[:4]:
        break

a=sequence[:len(sequence)-4]
x = sequence[0]
y = sequence[1]
print(f"The length of sequence starting with ({x},{y}) is {len(a)}")

first_term = 0
second_term = 5

sequence = [first_term, second_term]

max_iterations = 1000
current_iteration = 0

while current_iteration < max_iterations:
    next_term = (first_term + second_term) % 10
    sequence.append(next_term)
    first_term, second_term = second_term, next_term
    current_iteration += 1
    if len(sequence) > 4 and sequence[-4:] == sequence[:4]:
        break

a=sequence[:len(sequence)-4]
x = sequence[0]
y = sequence[1]
print(f"The length of sequence starting with ({x},{y}) is {len(a)}")

first_term = 2
second_term = 6

sequence = [first_term, second_term]

max_iterations = 1000
current_iteration = 0

while current_iteration < max_iterations:
    next_term = (first_term + second_term) % 10
    sequence.append(next_term)
    first_term, second_term = second_term, next_term
    current_iteration += 1
    if len(sequence) > 4 and sequence[-4:] == sequence[:4]:
        break

a=sequence[:len(sequence)-4]
x = sequence[0]
y = sequence[1]
print(f"The length of sequence starting with ({x},{y}) is {len(a)}")

first_term = 1
second_term = 3

sequence = [first_term, second_term]

max_iterations = 1000
current_iteration = 0

while current_iteration < max_iterations:
    next_term = (first_term + second_term) % 10
    sequence.append(next_term)
    first_term, second_term = second_term, next_term
    current_iteration += 1
    if len(sequence) > 4 and sequence[-4:] == sequence[:4]:
        break

a=sequence[:len(sequence)-4]
x = sequence[0]
y = sequence[1]
print(f"The length of sequence starting with ({x},{y}) is {len(a)}")



first_term = 0
second_term = 6

sequence = [first_term, second_term]

max_iterations = 1000
current_iteration = 0

while current_iteration < max_iterations:
    next_term = (first_term + second_term) % 10
    sequence.append(next_term)
    first_term, second_term = second_term, next_term
    current_iteration += 1
    if len(sequence) > 4 and sequence[-4:] == sequence[:4]:
        break

a=sequence[:len(sequence)-4]
x = sequence[0]
y = sequence[1]
print(f"The length of sequence starting with ({x},{y}) is {len(a)}")
# Out:
# The length of sequence starting with (0,0) is 1
# The length of sequence starting with (0,5) is 3
# The length of sequence starting with (2,6) is 4
# The length of sequence starting with (1,3) is 12
# The length of sequence starting with (0,6) is 20
